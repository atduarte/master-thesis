# %%
from sklearn import tree
from helpers import preview_tree

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
Y = iris.target

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)

# %%
sum(clf.predict_proba(iris.data[:, :]))
# Out:
# array([ 50.,  50.,  50.])

# %%
preview_tree(clf, iris.target_names)
